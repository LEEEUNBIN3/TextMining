# %% [markdown]
# # 엑소데이터

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# 사이트 연결, 헤더 사용 : 제가 참고 링크 드리겠슴다...이거 사용자 마다 아마 바꿔야 될것 같아요, 
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0 Safari/605.1.15'}
html = requests.get('https://www.genie.co.kr/detail/artistSong?xxnm=80220847', headers=headers).text
soup = BeautifulSoup(html, 'html.parser')

# 빈 리스트 만들기
song_id=[]
song_title=[]

# song id 찾기
for a in soup.find_all("tr",attrs= {"class" : "list"}):
    id=a.get('songid')
    song_id.append(id)
print(song_id)
    
# 곡제목(song title) 찾기
for a2 in soup.find_all("a",attrs= {"class" : "title ellipsis"}):
    ti=a2.get('title')
    song_title.append(ti)
    # 태그가<a>에 class도 같은게 있어서 그런지 none이 자꾸 들어가서 삭제해줬어요
    song_title = list (filter ( None , song_title))
print(song_title)

# song id와 곡제목으로 사전 만들기 (1~30위)
EXO_1 = dict(zip(song_id, song_title))
EXO_1
# Out:
# ['89655988', '90128240', '82145527', '82145523', '88468830', '82145524', '88350489', '81992735', '84215866', '83647188', '81922644', '85584767', '86350817', '87625527', '87295602', '85584768', '81922655', '86818658', '83215662', '87295601', '87414751', '85622746', '86535281', '86818656', '81992738', '85622732', '81922639', '82145526', '81922654', '86350816']
# ['Obsession', 'Confession', '첫 눈', '12월의 기적 (Miracles in December)', 'Love Shot', 'Christmas Day', 'Tempo', '으르렁 (Growl)', 'LOVE ME RIGHT', 'CALL ME BABY', "나비소녀 (Don't Go)", '불공평해 (Unfair)', 'Monster', 'Universe', 'Ko Ko Bop', 'Sing For You', '피터팬 (Peter Pan)', 'What I Want For Christmas', "December, 2014 (The Winter's Tale)", '전야 (前夜) (The Eve)', 'Power', '발자국 (On the snow)', 'Lotto', 'For Life', 'Lucky', 'Girl x Friend', "Baby, Don't Cry (인어의 눈물)", 'My turn to cry', '3.6.5', 'Lucky One']
# {'89655988': 'Obsession',
#  '90128240': 'Confession',
#  '82145527': '첫 눈',
#  '82145523': '12월의 기적 (Miracles in December)',
#  '88468830': 'Love Shot',
#  '82145524': 'Christmas Day',
#  '88350489': 'Tempo',
#  '81992735': '으르렁 (Growl)',
#  '84215866': 'LOVE ME RIGHT',
#  '83647188': 'CALL ME BABY',
#  '81922644': "나비소녀 (Don't Go)",
#  '85584767': '불공평해 (Unfair)',
#  '86350817': 'Monster',
#  '87625527': 'Universe',
#  '87295602': 'Ko Ko Bop',
#  '85584768': 'Sing For You',
#  '81922655': '피터팬 (Peter Pan)',
#  '86818658': 'What I Want For Christmas',
#  '83215662': "December, 2014 (The Winter's Tale)",
#  '87295601': '전야 (前夜) (The Eve)',
#  '87414751': 'Power',
#  '85622746': '발자국 (On the snow)',
#  '86535281': 'Lotto',
#  '86818656': 'For Life',
#  '81992738': 'Lucky',
#  '85622732': 'Girl x Friend',
#  '81922639': "Baby, Don't Cry (인어의 눈물)",
#  '82145526': 'My turn to cry',
#  '81922654': '3.6.5',
#  '86350816': 'Lucky One'}

# %%
import re

# 곡제목, 가사를 담을빈 리스트 만들기
song_title=[]
song_lyrics=[]

# 문장부호선언
pun = [',', '.', '?', '!', ':', ';', '(',')','’',r"'"]

# 불용어 텍스트 파일 불러오기
stopword_list=[]
with open('k_stopword.txt', 'r', encoding='utf-8') as file:
    stopword_list = file.readlines()
# print(stopword_list)

# 데이터셋을 만들기 위해 for문으로. 각 song_id를 가져옴
for i in song_id:
    # 사이트 연결, 헤더 사용 : 제가 링크 드리겠슴다...이거 사용자 마다 아마 바꿔야 될것 같아요, 
    headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0 Safari/605.1.15'}
    html = requests.get('https://www.genie.co.kr/detail/songInfo?xgnm='+i, headers=headers).text
    soup2 = BeautifulSoup(html, 'html.parser')
    
# 곡제목(song title) 찾기
    title=soup2.find('h2', class_='name').text
    
    # 제목 앞뒤 공백제거
    title=title.strip()
    song_title.append(title)
    lyrics=soup2.find("pre",id="pLyrics").find('p').text
    
    # 가사 앞뒤...사이사이 공백제거, splitlines은 문자열 내 개행문자 빼고 리스트로 돌려줌 -> 다시 조인
    lyrics=lyrics.splitlines()
    lyrics="".join( lyrics)
    
    # 가사에 있는 문장부호 제거
    lyrics = re.sub('|'.join(map(re.escape, pun)), '', lyrics)
    song_lyrics.append(lyrics)
    
    # 가사에 있는 불용어 제거
    song_lyrics2 = []
    for token in song_lyrics: 
        if token not in stopword_list: 
            song_lyrics2.append(token)

# 곡제목과 가사로 사전 만들기 (Train용 : 1~30위)
EXO_2 = dict(zip(song_title, song_lyrics2))
EXO_2
# Out:
# {'Obsession': '제발 이제 그만밤이 눈을 멀게 끔 하니넌 또 몰래 숨어들었지잠든 귓가 쓱 핥다 쳐다보다할퀴곤 웃어대끝도 없이 속삭이는 목소리Oh youre the bad dream kill나를 홀려 자꾸 불러너 있는 곳 그래 네게 오라고날 안다고 I dont think so뭔데 내게 파고들어 I dont think so넌 내 눈을 가려 I dont think so진실들을 덮어 I dont think so헛된 꿈 버려 I dont think so독을 뱉게 하지 마 I dont think so넌 날 다신 못 가져 I dont think soShut up and go awayThousand nights 지겹도록 말했어쫓고 쫓는 악몽 이젠 끝낼게불이 꺼진 exit light이제 그만 꺼져 줄래 내게서지겨워Ha 그만해 둬내 귓속에 쏟아대는 소리 Imma let it blow오감은 그것으로 쏠리고 곤두서고들어온 너는 제멋대로 휘저어한눈을 뜬 채로 잠들면 소리 없이 스며드는 the phantomIm so sick and tired of it불이 켜지면 네가 사라져 있길날 위한다고 I dont think so뭔데 내게 파고들어 I dont think so깊게 스며들어 I dont think so혼란스러워 I dont think soTake whatever I dont think so보이지도 마라 I dont think so넌 날 다신 못 가져 I dont think so집착하지 좀 마Thousand nights 지겹도록 말했어쫓고 쫓는 악몽 이젠 끝낼게불이 꺼진 exit light이제 그만 꺼져 줄래 내게서Blacken my heartCreepin dark night Stainin my soul잠든 듯 눈을 뜨면 거친 소름과선명한 그것의 흔적과주인 없는 names on the ground불러내 춤을 춰 tonight Say it what you like그래 너와 행복했었던 시간들을 알아이젠 끝내야 한다는 걸Forget everything yeah날 안다고 I dont think so뭔데 내게 파고들어 I dont think so넌 내 눈을 가려 I dont
�게 맞추고 있어 내 tempoBaby girl 내 어깨에 살짝 기댄 그대의아련한 향기가 다시 내 맘에소용돌이치며 몰아친다이대로 난 영원하고 싶다So dont mess up my tempo babyDont slow it up for me           Dont mess up my tempoDont mess up my tempoDont mess up my tempoDont mess up my tempoDont mess up my tempoDont mess up my tempoDont mess up my tempo내 눈을 바라보고 말해나의 귓가에만 닿게나만 사랑한다 말해나밖에 없다고 말해더 이상 흔들리지 않게절대 널 뺏기지 않게누구도 건들 수 없게내 곁에 너를 지킬게내 마음이 느껴지니나를 감싸 안은 유일한 나만의 savior 모두 그런 널 바라보게 돼I cant believe기다렸던 이런 느낌나만 듣고 싶은 그녀는 나의 멜로디하루 종일 go on and on and oh떠나지 않게 그녈 내 곁에Dont mess up my tempo 따라와 이건 충분히I said dont mess up my tempo완전히 다른 색의 beat어디에도 없을 이런 완벽한 1 2 3Dont mess up my tempo멈출 수 없는 이끌림',
#  '으르렁 (Growl)': 'yo okay 나 혹시 몰라 경고하는데 지금 위험해자꾸 나를 자극하지마 나도 날 몰라 숨이 자꾸 멎는다 네가 날 향해 걸어온다나를 보며 웃는다 너도 내게 끌리는지 눈앞이 다 캄캄해 네가 뚫어져라 쳐다볼 땐귓가에 가까워진 숨소리 날 미치게 만드는 너인걸아무도 널 못 보게 품에 감추고 싶어널 노리는 시선들 내 안에 일어난 거센 소용돌이 검은 그림자 내 안에 깨어나 널 보는두 눈에 불꽃이 튄다그녀 곁에서 모두 다 물러나 이젠 조금씩 사나워진다나 으르렁 으르렁 으르렁 대 나 으르렁 으르렁 으르렁 대나 으르렁 으르렁 으르렁 대 너 물러서지 않으면 다쳐도 몰라날이 선 눈빛과 베일듯한 긴장감 지금 탐색중이야 너의 주위를 babe oh--넌 그냥 그대로 있어 나만을 바라보면서 절대 널 보내지 않아 두고 봐 babe 흐린 공간속에서 선명하게 빛나는널 노리는 시선들 내안에 울리는 경보 울림소리검은 그림자 내안에 깨어나 널 보는두 눈에 불꽃이 튄다그녀 곁에서 모두 다 물러나 이젠 조금씩 사나워진다나 으르렁 으르렁 으르렁 대 나 으르렁 으르렁 으르렁 대나 으르렁 으르렁 으르렁 대 너 물러서지 않으면 다쳐도 몰라E X O 또 다른 늑대들이 볼세라 너무나 완벽한 내 여자라품속엔 부드럽게 너를 안고 너만을 위해서 나는 난폭해지고결국엔 강한 자가 얻게 되는 미인 자리가 없으니까 그냥 돌아가 I win가능성 제로야 닳으니까 그만 봐 그녀를 넘본다면 나를 먼저 넘어봐 우리 말곤 하나둘씩 지워버리자너하고 나만 여기 남아 멈춰진 듯이 워---검은 그림자 내안에 깨어나 널 보는 두 눈에 불꽃이 튄다그녀 곁에서 모두 다 물러나 이젠 조금씩 사나워진다나 으르렁 으르렁 으르렁 대 나 으르렁 으르렁 으르렁 대나 으르렁 으르렁 으르렁 대 너 물러서지 않으면 다쳐도 몰라나 으르렁 으르렁 으르렁 대 나 으르렁 으르렁 으르렁 대나 으르렁 으르렁 으르렁 대 너 물러서지 않으면 다쳐도 몰라',
EXO_df_1
# Out:
#         곡 번호                                곡 제목
# 0   89655988                           Obsession
# 1   90128240                          Confession
# 2   82145527                                 첫 눈
# 3   82145523      12월의 기적 (Miracles in December)
# 4   88468830                           Love Shot
# 5   82145524                       Christmas Day
# 6   88350489                               Tempo
# 7   81992735                         으르렁 (Growl)
# 8   84215866                       LOVE ME RIGHT
# 9   83647188                        CALL ME BABY
# 10  81922644                     나비소녀 (Don't Go)
# 11  85584767                       불공평해 (Unfair)
# 12  86350817                             Monster
# 13  87625527                            Universe
# 14  87295602                           Ko Ko Bop
# 15  85584768                        Sing For You
# 16  81922655                     피터팬 (Peter Pan)
# 17  86818658           What I Want For Christmas
# 18  83215662  December, 2014 (The Winter's Tale)
# 19  87295601                   전야 (前夜) (The Eve)
# 20  87414751                               Power
# 21  85622746                   발자국 (On the snow)
# 22  86535281                               Lotto
# 23  86818656                            For Life
# 24  81992738                               Lucky
# 25  85622732                       Girl x Friend
# 26  81922639            Baby, Don't Cry (인어의 눈물)
# 27  82145526                      My turn to cry
# 28  81922654                               3.6.5
# 29  86350816                           Lucky One

# %%
#곡제목과 가사 데이터 프레임 만들기 (All)
EXO_df_2 = pd.DataFrame(list(EXO_2.items()),columns=['곡 제목', '가사'])
EXO_df_2
# Out:
#                                   곡 제목  \
# 0                            Obsession
# 1                           Confession
# 2                                  첫 눈
# 3       12월의 기적 (Miracles in December)
# 4                            Love Shot
# 5                        Christmas Day
# 6                                Tempo
# 7                          으르렁 (Growl)
# 8                        LOVE ME RIGHT
# 9                         CALL ME BABY
# 10                     나비소녀 (Don't Go)
# 11                       불공평해 (Unfair)
# 12                             Monster
# 13                            Universe
# 14                           Ko Ko Bop
# 15                        Sing For You
# 16                     피터팬 (Peter Pan)
# 17           What I Want For Christmas
# 18  December, 2014 (The Winter's Tale)
# 19                   전야 (前夜) (The Eve)
# 20                               Power
# 21                   발자국 (On the snow)
# 22                               Lotto
# 23                            For Life
# 24                               Lucky
# 25                       Girl x Friend
# 26            Baby, Don't Cry (인어의 눈물)
# 27                      My turn to cry
# 28                               3.6.5
# 29                           Lucky One
#
#                                                    가사
# 0   제발 이제 그만밤이 눈을 멀게 끔 하니넌 또 몰래 숨어들었지잠든 귓가 쓱 핥다 쳐다...
# 1   Yo I Just wanna know youTime for confessionTim...
# 2   첫눈 오는 이런 오후에너에게 전화를걸 수만 있다면 기쁠텐데벌써 일년이 지났는데난 아...
# 3   보이지 않는 널 찾으려고 애쓰다 들리지 않는 널 들으려 애쓰다 보이지 않던 게 보이...
# 4   차갑도록 서롤 겨눈 채날이 선 듯 그 목소리엔숨막히는 것만 가득해Oh oh oh o...
# 5   설렘에 부풀어 눈을 뜨는 아침선물의 리본끈을 풀어보는 느낌너를 알아가는 날이면 날마...
# 6   I cant believe기다렸던 이런 느낌나만 듣고 싶은 그녀는 나의 멜로디하루 ...
# 7   yo okay 나 혹시 몰라 경고하는데 지금 위험해자꾸 나를 자극하지마 나도 날 몰...
# 8   Oh Yeah CmonTake your time왠지 두근대는 밤이야Na Na Na ...
# 9   이 거리는 완전 난리야사람들 사이는 남이야함께하는 매 순간이Like BOOM BOO...
# 10  조그만 날갯짓널 향한 이끌림 나에게 따라오라손짓한 것 같아서애절한 눈빛과무언의 이야...
# 11  그렇게 날 보고 웃으면 Girl dont you know아무렇지 않기는 힘들어다 마...
# 12  She got me gone crazy왜 심장이 뛰니 넌 아름다워 나의 Goddes...
# 13  마음과 반대로 아픈 말이 나와너를 힘들게 했던 나도 내가 힘든 걸다짐과 다르게 나아...
# 14  Shimmie shimmie Ko Ko BopI think I like it긴장은 ...
# 15  내 낡은 기타를 들어 하지 못한 고백을혹은 고집스레 삼킨 이야기를노래 하나 만든 척...
# 16  낡은 일기장 먼지를 털어내 문득 펼친 곳 그 속엔 해맑게  네가 있어 아직 넌 그대...
# 17  어느새 우리함께 한 다섯 번째 크리스마스어느덧 우리꽤나 잘 어울리지 YeahI th...
# 18  거리에 하나 둘 늘어가는 불빛처럼다가온 하얀 겨울Woo~ 참 좋았던 계절 지나때론 ...
# 19  똑바로 봐 Whats the situation 당황한 너의 시선 너머 끝내 무너지는...
# 20  머뭇거리지 마 Move on자 시간이 없어너의 미래는 바로 상상에 달렸어두려움 따윈...
# 21  BabyOoh Yeah Oh여기 흰 눈 위에 너의 걸음 따라서Listen더 가버림 ...
# 22  yeah yeah yeahyeah yeah yeah yeahOh yeah yeaho...
# 23  천사의 얼굴로내게로 왔던 미스터리너란 온기네 곁에 머물며널 사랑할 그 한 사람나라니...
# 24  같은 나라에 태어나서같은 언어로 말을 해서참 행운이야 참 다행이야세상에 당연한 건 ...
# 25  Ooh yeah yeah-yeah oh눈으로 널 기억해 머리로 널 그려내항상 난 I...
# 26  더는 망설이지 마 제발 내 심장을 거두어 가그래 날카로울수록 좋아 달빛 조차도 눈을...
# 27  악몽을 꿨어요울던 그대를 안아주기 전에꿈에서 깨어 버렸죠서글픈 맘에 커튼을 열어달빛...
# 28  세 번 까진 부딪혀 봐 여섯 번쯤 울지라도 다섯 번 더 이겨내면 끝이 보이기 시작해...
# 29  Oh 태양이 뜬다 널 찾아줄 지도를 들고 좌표를 따라 나서는 항로No matter ...

# %%
#곡 번호를 기준삼아 데이터 프레임 사전 조인
EXO_final = pd.merge(EXO_df_1, EXO_df_2, on='곡 제목')
EXO_final
# Out:
#         곡 번호                                곡 제목  \
# 0   89655988                           Obsession
# 1   90128240                          Confession
# 2   82145527                                 첫 눈
# 3   82145523      12월의 기적 (Miracles in December)
# 4   88468830                           Love Shot
# 5   82145524                       Christmas Day
# 6   88350489                               Tempo
# 7   81992735                         으르렁 (Growl)
# 8   84215866                       LOVE ME RIGHT
# 9   83647188                        CALL ME BABY
# 10  81922644                     나비소녀 (Don't Go)
# 11  85584767                       불공평해 (Unfair)
# 12  86350817                             Monster
# 13  87625527                            Universe
# 14  87295602                           Ko Ko Bop
# 15  85584768                        Sing For You
# 16  81922655                     피터팬 (Peter Pan)
# 17  86818658           What I Want For Christmas
# 26  더는 망설이지 마 제발 내 심장을 거두어 가그래 날카로울수록 좋아 달빛 조차도 눈을...
# 27  악몽을 꿨어요울던 그대를 안아주기 전에꿈에서 깨어 버렸죠서글픈 맘에 커튼을 열어달빛...
# 28  세 번 까진 부딪혀 봐 여섯 번쯤 울지라도 다섯 번 더 이겨내면 끝이 보이기 시작해...
# 29  Oh 태양이 뜬다 널 찾아줄 지도를 들고 좌표를 따라 나서는 항로No matter ...

# %%
# 앨범 형태별 수->뭔가 시각화 하기 좋을 것 같아서 추가 합니다

# 사이트 연결, 헤더 사용 : 제가 참고 링크 드리겠슴다...이거 사용자 마다 아마 바꿔야 될것 같아요, 
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0 Safari/605.1.15'}
html = requests.get('https://www.genie.co.kr/detail/artistAlbum?xxnm=80220847', headers=headers).text
soup = BeautifulSoup(html, 'html.parser')

# 빈 리스트 만들기
album_num=[]
    
# 곡 형태별 수 찾기
for num in soup.find_all("em"):
    album_num.append(num.text)
# 숫자가 0인 값 빼기
album_num=list(filter(('0').__ne__, album_num))
    
# 순서대로 전체앨범, 정규앨범, 싱글/EP, 기타앨범, 참여앨범
print(album_num)

#곡번호와 가사 데이터 프레임 만들기
EXO_num_df = pd.DataFrame(album_num, columns=['각 앨범 수'], index=['전체앨범', '정규앨범', '싱글/EP', '기타앨범', '참여앨범'])
EXO_num_df
# Out:
# ['54', '12', '10', '5', '27']
#       각 앨범 수
# 전체앨범      54
# 정규앨범      12
# 싱글/EP     10
# 기타앨범       5
# 참여앨범      27

# %% [markdown]
# ## 트와이스 데이터

# %%
# 사이트 연결, 헤더 사용 : 제가 참고 링크 드리겠슴다...이거 사용자 마다 아마 바꿔야 될것 같아요, 
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0 Safari/605.1.15'}
html = requests.get('https://www.genie.co.kr/detail/artistSong?xxnm=80463902', headers=headers).text
soup = BeautifulSoup(html, 'html.parser')

# 빈 리스트 만들기
song_id=[]
song_title=[]

# song id 찾기
for a in soup.find_all("tr",attrs= {"class" : "list"}):
    id=a.get('songid')
    song_id.append(id)
print(song_id)
    
# 곡제목(song title) 찾기
for a2 in soup.find_all("a",attrs= {"class" : "title ellipsis"}):
    ti=a2.get('title')
    song_title.append(ti)
    # 태그가<a>에 class도 같은게 있어서 그런지 none이 자꾸 들어가서 삭제해줬어요
    song_title = list (filter ( None , song_title))
print(song_title)

# song id와 곡제목으로 사전 만들기
TW_1 = dict(zip(song_id, song_title))
TW_1
# Out:
# ['91165220', '90313511', '88824340', '89378658', '87590605', '88353506', '88098432', '87590604', '87893782', '86161553', '86962806', '86677293', '87490163', '85260893', '87122182', '91165222', '91165221', '91165223', '88458580', '91165226', '91165225', '91165227', '91165231', '91165230', '91165224', '91165232', '91165229', '91165228', '88353512', '91519451']
# ["I CAN'T STOP ME", 'MORE & MORE', 'FANCY', 'Feel Special', 'Merry & Happy', 'YES or YES', 'Dance The Night Away', 'Heart Shaker', 'What is Love?', 'CHEER UP', 'KNOCK KNOCK', 'TT', 'LIKEY', 'OOH-AHH하게', 'SIGNAL', 'UP NO MORE', 'HELL IN HEAVEN', 'DO WHAT WE LIKE', '올해 제일 잘한 일', 'QUEEN', 'BELIEVER', 'GO HARD', 'SAY SOMETHING', 'DEPEND ON YOU', 'BRING IT BACK', 'BEHIND THE MASK', 'HANDLE IT', 'SHOT CLOCK', 'BDZ (Korean Ver.)', "I CAN'T STOP ME (English Ver.)"]
# {'91165220': "I CAN'T STOP ME",
#  '90313511': 'MORE & MORE',
#  '88824340': 'FANCY',
#  '89378658': 'Feel Special',
#  '87590605': 'Merry & Happy',
#  '88353506': 'YES or YES',
#  '88098432': 'Dance The Night Away',
#  '87590604': 'Heart Shaker',
#  '87893782': 'What is Love?',
#  '86161553': 'CHEER UP',
#  '86962806': 'KNOCK KNOCK',
#  '86677293': 'TT',
#  '87490163': 'LIKEY',
#  '85260893': 'OOH-AHH하게',
#  '87122182': 'SIGNAL',
#  '91165222': 'UP NO MORE',
#  '91165221': 'HELL IN HEAVEN',
#  '91165223': 'DO WHAT WE LIKE',
#  '88458580': '올해 제일 잘한 일',
#  '91165226': 'QUEEN',
#  '91165225': 'BELIEVER',
#  '91165227': 'GO HARD',
#  '91165231': 'SAY SOMETHING',
#  '91165230': 'DEPEND ON YOU',
#  '91165224': 'BRING IT BACK',
#  '91165232': 'BEHIND THE MASK',
#  '91165229': 'HANDLE IT',
#  '91165228': 'SHOT CLOCK',
#  '88353512': 'BDZ (Korean Ver.)',
#  '91519451': "I CAN'T STOP ME (English Ver.)"}

# %%
# 곡제목, 가사를 담을빈 리스트 만들기
song_title=[]
song_lyrics=[]

# 데이터셋을 만들기 위해 for문으로. 각 song_id를 가져옴
for i in song_id:
    # 사이트 연결, 헤더 사용 : 제가 링크 드리겠슴다...이거 사용자 마다 아마 바꿔야 될것 같아요, 
    headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0 Safari/605.1.15'}
    html = requests.get('https://www.genie.co.kr/detail/songInfo?xgnm='+i, headers=headers).text
    soup2 = BeautifulSoup(html, 'html.parser')
    
# 곡제목(song title) 찾기
    title=soup2.find('h2', class_='name').text
    
    # 제목 앞뒤 공백제거
    title=title.strip()
    song_title.append(title)
    lyrics=soup2.find("pre",id="pLyrics").find('p').text
    
    # 가사 앞뒤...사이사이 공백제거, splitlines은 문자열 내 개행문자 빼고 리스트로 돌려줌 -> 다시 조인
    lyrics=lyrics.splitlines()
    lyrics="".join( lyrics)
    
    # 가사에 있는 문장부호 제거
    lyrics = re.sub('|'.join(map(re.escape, pun)), '', lyrics)
    song_lyrics.append(lyrics)
    
    # 가사에 있는 불용어 제거
    song_lyrics2 = []
    for token in song_lyrics: 
        if token not in stopword_list: 
            song_lyrics2.append(token)

# 곡제목과 가사로 사전 만들기 (All)
TW_2 = dict(zip(song_title, song_lyrics2))
TW_2
# Out:
#  'TT': '이러지도 못하는데 저러지도 못하네그저 바라보며 ba-ba-ba-baby매일 상상만 해 이름과 함께 쓱 말을 놨네 baby아직 우린 모르는 사인데아무거나 걸쳐도 아름다워거울 속 단 둘이서 하는 fashion show show이번에 정말 꼭꼭 내가 먼저 talk talk다짐 뿐인걸 매번 다짐 뿐인걸나나나나나나나콧노래가 나오다가 나도 몰래눈물 날 것 같애아닌 것 같애 내가 아닌 것 같애I love you so much이미 난 다 컸다고 생각하는데어쩌면 내 맘인데 왜 내 맘대로 할 수 없는 건 왜밀어내려고 하면 할수록자꾸 끌려 왜 자꾸 자꾸 끌려 babyIm like TTJust like TT이런 내 맘 모르고 너무해 너무해Im like TTJust like TTTell me that youd be my baby어처구니 없다고 해얼굴 값을 못한대전혀 위로 안돼 ba-ba-ba-baby미칠 것 같애 이 와중에 왜배는 또 고픈 건데하루 종일 먹기만 하는데맴매매매 아무 죄도 없는 인형만 때찌종일 앉아있다가 엎드렸다 시간이 획획획피부는 왜 이렇게 또 칙칙자꾸 틱틱 거리고 만 싶지엄만 귀찮게 계속 왜왜왜왜왜나나나나나나나콧노래가 나오다가 나도 몰래짜증날 것 같애 화날 것 같애이런 애가 아닌데I love you so much이미 난 다 컸다고 생각하는데어쩌면 내 맘인데 왜 내 맘대로 할 수 없는 건 왜밀어내려고 하면 할수록자꾸 끌려 왜 자꾸 자꾸 끌려 babyIm like TTJust like TT이런 내 맘 모르고 너무해 너무해Im like TTJust like TTTell me that youd be my baby혹시 이런 나를 알까요이대로 사라져 버리면 안돼요이번엔 정말 꼭꼭 내가 먼저 talk talk다짐 뿐인걸 매번 다짐 뿐인걸이미 난 다 컸다고 생각하는데어쩌면 내 맘인데 왜 내 맘대로 할 수 없는 건 왜밀어내려고 하면 할수록자꾸 끌려 왜 자꾸 자꾸 끌려 babyIm like TTJust like TT이런 내 맘 모르고 너무해 너무해Im like TTJust like TTTell me that youd be my baby',
#  'LIKEY': '설렌다 Me Likey Me Likey Likey Likey Me Likey Likey Likey두근두근두근 Heart HeartMe Likey Me Likey Likey Likey Me Likey Likey Likey두근두근두근 자꾸 드러내고 싶지 자꾸만 사소한 것 하나까지 전부다작은 화면 속에 내가 제일 예뻐 보이고파 아직은 감춰 이런 내 마음 꾹꾹  멋 부린다는 건 정말 귀찮은 거 그렇다고 절대 대충할 수가 없는걸 매일 가슴 뛰게 해 이건 네가 몰라야만 돼그러면서 뻔뻔하게BB크림 파파파 립스틱을 맘맘마 카메라에 담아볼까 예쁘게이거 보면 웃어줘 그리고 꼭 눌러줘저 밑에 앙증맞고 새빨간 Heart Heart근데 좋아요란 말은 뻔해 내 맘 표현하기엔 부족한데근데 좋아요 잠도 못 자도 지각하게 돼도 좋은걸설렌다 Me Likey Me Likey Likey Likey Me Likey Likey Likey두근두근두근 Heart HeartMe Likey Me Likey Likey Likey Me Likey Likey
# 15  91165222                      UP NO MORE
# 16  91165221                  HELL IN HEAVEN
# 17  91165223                 DO WHAT WE LIKE
# 18  88458580                      올해 제일 잘한 일
# 19  91165226                           QUEEN
# 20  91165225                        BELIEVER
# 21  91165227                         GO HARD
# 22  91165231                   SAY SOMETHING
# 23  91165230                   DEPEND ON YOU
# 24  91165224                   BRING IT BACK
# 25  91165232                 BEHIND THE MASK
# 26  91165229                       HANDLE IT
# 27  91165228                      SHOT CLOCK
# 28  88353512               BDZ (Korean Ver.)
# 29  91519451  I CAN'T STOP ME (English Ver.)

# %%
#곡제목과 가사 데이터 프레임 만들기
TW_df_2 = pd.DataFrame(list(TW_2.items()),columns=['곡 제목', '가사'])
TW_df_2
# Out:
#                               곡 제목  \
# 0                  I CAN'T STOP ME
# 1                      MORE & MORE
# 2                            FANCY
# 3                     Feel Special
# 4                    Merry & Happy
# 5                       YES or YES
# 6             Dance The Night Away
# 7                     Heart Shaker
# 8                    What is Love?
# 9                         CHEER UP
# 10                     KNOCK KNOCK
# 11                              TT
# 12                           LIKEY
# 13                       OOH-AHH하게
# 14                          SIGNAL
# 15                      UP NO MORE
# 16                  HELL IN HEAVEN
# 17                 DO WHAT WE LIKE
# 18                      올해 제일 잘한 일
# 19                           QUEEN
# 20                        BELIEVER
# 21                         GO HARD
# 22                   SAY SOMETHING
# 23                   DEPEND ON YOU
# 24                   BRING IT BACK
# 25                 BEHIND THE MASK
# 26                       HANDLE IT
# 27                      SHOT CLOCK
# 28               BDZ (Korean Ver.)
# 29  I CAN'T STOP ME (English Ver.)
#
#                                                    가사
# 0   알람이 울려대 Ring ring a ling서로의 눈길이 닿을 때마다알면서 빙빙 도...
# 1   I know I want it입에 바른 소린 이제 그만할게Cause I deserv...
# 2   지금 하늘 구름 색은 Tropical yeah저 태양 빨간빛 네 두 볼 같아Oh t...
# 3   그런 날이 있어갑자기 혼자인 것만 같은 날어딜 가도 내 자리가 아닌 것만 같고고갠 ...
# 4   매년 12월 달력을 넘길 때마다시작되는 그 알 수 없는 허전함은모른 척을 해봐도 밀...
# 5   Hey boyLook Im gonna make thissimple for you y...
# 6   나나나나나나나 나나나나나나나You and me in the moonlight 별 꽃...
# 7   Yeah Yeah Yeah YeahCome and be my love Come an...
# 8   매일같이 영화 속에서나책 속에서나 드라마 속에서 사랑을 느껴 Um- 사랑을 배워내 ...
# 9   매일 울리는 벨벨벨이젠 나를 배려 해줘배터리 낭비하긴 싫어자꾸만 봐 자꾸 자꾸만 와...
# 10  열두시가 되면 닫혀요조금만 서둘러 줄래요Knock knock knock knock ...
# 11  이러지도 못하는데 저러지도 못하네그저 바라보며 ba-ba-ba-baby매일 상상만 ...
# 12  설렌다 Me Likey Me Likey Likey Likey Me Likey Lik...
# 13  모두 나를 가지고매일 가만 안 두죠내가 너무 예쁘죠나 때문에 다 힘들죠어딜 걷고 있...
# 14  Trying to let you knowSign을 보내 signal 보내I must...
# 15  Uh yeah yeah어둠이 짙게 깔린 이 밤 홀로아직도 환한 내 하룰 끄지 못하고...
# 16  네 눈은 가시 박힌 Diamond 같애 천사와 악마가 왔다 갔다 해 천국과 지옥은 ...
# 17  물속에서 막힌귀를 뚫고서 울려와날 부르는 목소리가 Yeah저 물결을 타고나를 향해서...
# 18  The best thing I ever didDecember 1년의 끝을 너와 I ...
# 19  Its a showBut you shouldnt forgetI know what y...
# 20  I believeIm a believer oh yeahBelieverYoure on...
# 21  Woah-uh-uh We just go hardWe just go hard till...
# 22  매일이 별다를 것 없던 기억들이 변해가는 것 같아Where are we 우린 어디쯤...
# 23  작은 소리들의 기적꿈속의 믿음을 기억하게 해주는 손길을 매 순간 더 세게 잡아불 꺼...
# 24  Ooh no Im gonna bring it back hmmBring it back...
# 25  뱉은 숨을 마신 뒤 한숨만 남겨뒀지네가 나를 떠난 뒤 오늘만 살게 됐지Round a...
# 26  말라버린 내 두 눈에 바람이 불어 시려 굳이 애써 참은 눈물이 흘러괜찮을 거라 말해...
# 27  Pull the trigger 한 방에 Shot기회는 딱 한 번뿐이야 망설일 시간은...
# 28  Like a bulldozer Like a tankLike a soldier 무너뜨...
# 29  Im hearing all the alarms ring-a-lingThey go o...

# %%
#곡 번호를 기준삼아 데이터 프레임 사전 조인
TW_final = pd.merge(TW_df_1, TW_df_2, on='곡 제목')
TW_final
# Out:
#         곡 번호                            곡 제목  \
# 0   91165220                 I CAN'T STOP ME
# 1   90313511                     MORE & MORE
# 2   88824340                           FANCY
# 3   89378658                    Feel Special
# 4   87590605                   Merry & Happy
# 5   88353506                      YES or YES
# 6   88098432            Dance The Night Away
# 7   87590604                    Heart Shaker
# 8   87893782                   What is Love?
# 9   86161553                        CHEER UP
# 10  86962806                     KNOCK KNOCK
# 11  86677293                              TT
# 12  87490163                           LIKEY
# 13  85260893                       OOH-AHH하게
# 14  87122182                          SIGNAL
# 15  91165222                      UP NO MORE
# 16  91165221                  HELL IN HEAVEN
# 17  91165223                 DO WHAT WE LIKE
# 18  88458580                      올해 제일 잘한 일
# 19  91165226                           QUEEN
# 20  91165225                        BELIEVER
# 21  91165227                         GO HARD
# 22  91165231                   SAY SOMETHING
# 23  91165230                   DEPEND ON YOU
# 24  91165224                   BRING IT BACK
# 25  91165232                 BEHIND THE MASK
# 26  91165229                       HANDLE IT
# 27  91165228                      SHOT CLOCK
# 28  88353512               BDZ (Korean Ver.)
# 29  91519451  I CAN'T STOP ME (English Ver.)
#
#                                                    가사
# 0   알람이 울려대 Ring ring a ling서로의 눈길이 닿을 때마다알면서 빙빙 도...
# 1   I know I want it입에 바른 소린 이제 그만할게Cause I deserv...
# 2   지금 하늘 구름 색은 Tropical yeah저 태양 빨간빛 네 두 볼 같아Oh t...
# 3   그런 날이 있어갑자기 혼자인 것만 같은 날어딜 가도 내 자리가 아닌 것만 같고고갠 ...
# 4   매년 12월 달력을 넘길 때마다시작되는 그 알 수 없는 허전함은모른 척을 해봐도 밀...
# 5   Hey boyLook Im gonna make thissimple for you y...
# 6   나나나나나나나 나나나나나나나You and me in the moonlight 별 꽃...
# 7   Yeah Yeah Yeah YeahCome and be my love Come an...
# 8   매일같이 영화 속에서나책 속에서나 드라마 속에서 사랑을 느껴 Um- 사랑을 배워내 ...
# 9   매일 울리는 벨벨벨이젠 나를 배려 해줘배터리 낭비하긴 싫어자꾸만 봐 자꾸 자꾸만 와...
# 10  열두시가 되면 닫혀요조금만 서둘러 줄래요Knock knock knock knock ...
# 11  이러지도 못하는데 저러지도 못하네그저 바라보며 ba-ba-ba-baby매일 상상만 ...
# 12  설렌다 Me Likey Me Likey Likey Likey Me Likey Lik...
# 13  모두 나를 가지고매일 가만 안 두죠내가 너무 예쁘죠나 때문에 다 힘들죠어딜 걷고 있...
# 14  Trying to let you knowSign을 보내 signal 보내I must...
# 15  Uh yeah yeah어둠이 짙게 깔린 이 밤 홀로아직도 환한 내 하룰 끄지 못하고...
# 16  네 눈은 가시 박힌 Diamond 같애 천사와 악마가 왔다 갔다 해 천국과 지옥은 ...
# 17  물속에서 막힌귀를 뚫고서 울려와날 부르는 목소리가 Yeah저 물결을 타고나를 향해서...
# 18  The best thing I ever didDecember 1년의 끝을 너와 I ...
# 19  Its a showBut you shouldnt forgetI know what y...
# 20  I believeIm a believer oh yeahBelieverYoure on...
# 21  Woah-uh-uh We just go hardWe just go hard till...
# 22  매일이 별다를 것 없던 기억들이 변해가는 것 같아Where are we 우린 어디쯤...
# 23  작은 소리들의 기적꿈속의 믿음을 기억하게 해주는 손길을 매 순간 더 세게 잡아불 꺼...
# 24  Ooh no Im gonna bring it back hmmBring it back...
# 25  뱉은 숨을 마신 뒤 한숨만 남겨뒀지네가 나를 떠난 뒤 오늘만 살게 됐지Round a...
# 26  말라버린 내 두 눈에 바람이 불어 시려 굳이 애써 참은 눈물이 흘러괜찮을 거라 말해...
# 27  Pull the trigger 한 방에 Shot기회는 딱 한 번뿐이야 망설일 시간은...
# 28  Like a bulldozer Like a tankLike a soldier 무너뜨...
# 29  Im hearing all the alarms ring-a-lingThey go o...

# %%
# 앨범 형태별 수->뭔가 시각화 하기 좋을 것 같아서 추가 합니다

# 사이트 연결, 헤더 사용 : 제가 참고 링크 드리겠슴다...이거 사용자 마다 아마 바꿔야 될것 같아요, 
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0 Safari/605.1.15'}
html = requests.get('https://www.genie.co.kr/detail/artistAlbum?xxnm=80463902', headers=headers).text
soup = BeautifulSoup(html, 'html.parser')

# 빈 리스트 만들기
album_num=[]
    
# 곡 형태별 수 찾기
for num in soup.find_all("em"):
    album_num.append(num.text)
# 숫자가 0인 값 빼기
album_num=list(filter(('0').__ne__, album_num))
    
# 순서대로 전체앨범, 정규앨범, 싱글/EP, 기타앨범, 참여앨범
print(album_num)

#곡번호와 가사 데이터 프레임 만들기
TW_num_df = pd.DataFrame(album_num, columns=['각 앨범 수'], index=['전체앨범', '정규앨범', '싱글/EP', '기타앨범', '참여앨범'])
TW_num_df
# Out:
# ['34', '7', '23', '2', '2']
#       각 앨범 수
# 전체앨범      34
# 정규앨범       7
# 싱글/EP     23
# 기타앨범       2
# 참여앨범       2

# %% [markdown]
# ## 품사태깅(엑소)

# %%
#품사 태깅을 위한 konlpy Import, okt는 한국어 분석기
from konlpy.tag import Okt
twi_tagger = Okt()
from konlpy.utils import pprint

# %%
 # 토큰화를 위한 모듈 호출
import nltk
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
tokenizer

# 불용어 제거를 위한 모듈 호출
from nltk.corpus import stopwords


# (돈, Noun) -> "돈/Noun" 형태로 바꿈
def tokenizer_twit(doc):
    return ['/'.join(t) for t in twi_tagger.pos(doc, norm=True, stem=True)]

# %%
# 리뷰 단어 리스트 형태로 만드는 함수
def review_to_wordlist(review):
    try:
        review_text = BeautifulSoup(review.strip()).get_text()
    except AttributeError:
        review_text = ""
    review_words = tokenizer_twit(review_text)
    return review_words

# %%
#단어를 품사 단위로 
words=[]
for review in EXO_final["가사"]:
    words += review_to_wordlist(review)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
#단어 단위로 분해 확인
pprint(words[:10])
# Out:
# ['제발/Noun',
#  '이제/Noun',
#  '그만/Modifier',
#  '밤/Noun',
#  '이/Josa',
#  '눈/Noun',
#  '을/Josa',
#  '멀다/Adjective',
#  '끄다/Verb',
#  '하니/Noun']

# %%
##문서 탐색을 위한 기능 호출
words_nltk = nltk.Text(words, name="Words in lyrics")

# %%
#전체 단어 수 세기
len(words_nltk.vocab())
# Out:
# 1921

# %%
# 결과 저장
EXO_result2 = words_nltk.vocab().most_common(980)
# 데이터 프레임으로 생성
EXO_result2 = pd.DataFrame(EXO_result2);EXO_result2[:20]
# 결과로 가장 많이 나온게 ''<-이거인데 버릴지 말지 고민 Let's이런식으로 쓰여서
# Out:
#                 0    1
# 0          너/Noun  159
# 1         하다/Verb  150
# 2          에/Josa  130
# 3          을/Josa  125
# 4          이/Josa  118
# 5          의/Josa  108
# 6        oh/Alpha   86
# 7          내/Noun   84
# 8          나/Noun   77
# 9   -/Punctuation   73
# 10         널/Noun   72
# 11         를/Josa   71
# 12         가/Josa   68
# 13        I/Alpha   66
# 14      the/Alpha   62
# 15         은/Josa   61
# 16         눈/Noun   54
# 17     yeah/Alpha   53
# 18   있다/Adjective   50
# 19       me/Alpha   50

# %%
EXO_result2.columns = ['word', 'counts']
EXO_result2[:10]
#단어와 품사가 합쳐진 것을 나눠줌
EXO_result2['단어'], EXO_result2['품사'] = zip(*EXO_result2.word.map(lambda x: x.split('/')))
EXO_result2 = EXO_result2.drop(['word'], 1)
#보기 좋은 순서로 재배치
EXO_result2 = EXO_result2[['단어', '품사', 'counts']]

# %%
#명사만 10위까지 뽑기
Noun = EXO_result2['품사'] == "Noun"
EXO_result2[Noun][:10]
# Out:
#    단어    품사  counts
# 0   너  Noun     159
# 7   내  Noun      84
# 8   나  Noun      77
# 10  널  Noun      72
# 16  눈  Noun      54
# 20  그  Noun      49
# 22  네  Noun      47
# 26  날  Noun      42
# 29  말  Noun      40
# 33  더  Noun      39

# %%
#동사만 10위까지 뽑기
Verb = EXO_result2['품사'] == "Verb"
EXO_result2[Verb][:10]
# Out:
#      단어    품사  counts
# 1    하다  Verb     150
# 24   보다  Verb      47
# 34   않다  Verb      39
# 36   내다  Verb      37
# 43   되다  Verb      31
# 61   들다  Verb      23
# 69   돼다  Verb      21
# 75   가다  Verb      19
# 76  버리다  Verb      19
# 78  모르다  Verb      19

# %%
#형용사만 10위까지
Adjective = EXO_result2['품사'] == "Adjective"
EXO_result2[Adjective][:10]
# Out:
#        단어         품사  counts
# 18     있다  Adjective      50
# 21     없다  Adjective      48
# 31     같다  Adjective      40
# 91     좋다  Adjective      17
# 97    그렇다  Adjective      16
# 109   하얗다  Adjective      15
# 115   아니다  Adjective      15
# 211  아름답다  Adjective       9
# 225   이렇다  Adjective       8
# 241  영원하다  Adjective       8

# %%
## 품사태깅(트와이스)

# %%
#단어를 품사 단위로 
words=[]
for review in TW_final["가사"]:
    words += review_to_wordlist(review)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
##문서 탐색을 위한 기능 호출
words_nltk = nltk.Text(words, name="Words in lyrics")

# %%
#단어 단위로 분해 확인
pprint(words[:10])
# Out:
# ['알람/Noun',
#  '이/Josa',
#  '울리다/Verb',
#  'Ring/Alpha',
#  'ring/Alpha',
#  'a/Alpha',
#  'ling/Alpha',
#  '서로/Noun',
#  '의/Josa',
#  '눈길/Noun']

# %%
#전체 단어 수 세기
len(words_nltk.vocab())
# Out:
# 1871

# %%
# 결과 저장
TW_result2 = words_nltk.vocab().most_common(980)
# 데이터 프레임으로 생성
TW_result2 = pd.DataFrame(TW_result2);TW_result2[:20]
# 결과로 가장 많이 나온게 ''<-이거인데 버릴지 말지 고민 Let's이런식으로 쓰여서
# Out:
#                0    1
# 0        하다/Verb  167
# 1        I/Alpha  134
# 2         이/Josa  115
# 3         을/Josa  109
# 4    knock/Alpha   98
# 5       me/Alpha   97
# 6         내/Noun   92
# 7         가/Josa   91
# 8      you/Alpha   90
# 9         너/Noun   87
# 10     the/Alpha   85
# 11        에/Josa   79
# 12      it/Alpha   76
# 13    know/Alpha   72
# 14        더/Noun   67
# 15  있다/Adjective   66
# 16  없다/Adjective   64
# 17        를/Josa   64
# 18       않다/Verb   60
# 19   wanna/Alpha   59

# %%
TW_result2.columns = ['word', 'counts']
TW_result2[:10]
#단어와 품사가 합쳐진 것을 나눠줌
TW_result2['단어'], TW_result2['품사'] = zip(*TW_result2.word.map(lambda x: x.split('/')))
TW_result2 = TW_result2.drop(['word'], 1)
#보기 좋은 순서로 재배치
TW_result2 = TW_result2[['단어', '품사', 'counts']]

# %%
#명사만 10위까지 뽑기
Noun = TW_result2['품사'] == "Noun"
TW_result2[Noun][:10]
# Out:
#    단어    품사  counts
# 6   내  Noun      92
# 9   너  Noun      87
# 14  더  Noun      67
# 23  날  Noun      53
# 24  맘  Noun      50
# 25  것  Noun      48
# 31  네  Noun      44
# 44  나  Noun      34
# 46  이  Noun      33
# 49  말  Noun      32

# %%
#동사만 10위까지 뽑기
Verb = TW_result2['품사'] == "Verb"
TW_result2[Verb][:10]
# Out:
#      단어    품사  counts
# 0    하다  Verb     167
# 18   않다  Verb      60
# 36   보다  Verb      40
# 40  모르다  Verb      35
# 47   가다  Verb      33
# 52   싶다  Verb      29
# 55  보내다  Verb      28
# 64  버리다  Verb      25
# 68   되다  Verb      24
# 69   돼다  Verb      24

# %%
#형용사만 10위까지
Adjective = TW_result2['품사'] == "Adjective"
TW_result2[Adjective][:10]
# Out:
#       단어         품사  counts
# 15    있다  Adjective      66
# 16    없다  Adjective      64
# 35    같다  Adjective      41
# 42   어떻다  Adjective      35
# 63   그렇다  Adjective      25
# 93   원하다  Adjective      19
# 104   싫다  Adjective      17
# 107  아니다  Adjective      17
# 119  이렇다  Adjective      16
# 142   좋다  Adjective      13

# %%
# 알고리즘 구현

# %%
# 엑소 노래별 가사의 단어 종류별 개수 (조사는 무의미하므로 포함 안함)
cnt_Total = []
ratio_Noun = []
ratio_Verb = []
ratio_Adject = []
ratio_Alpha = []
titles = []

#단어를 품사 단위로 (각 가사별로 조사할 예정)
for review, title in zip(EXO_final["가사"], EXO_final["곡 제목"]):
    titles.append(title)
    cnt_n = 0
    cnt_v = 0
    cnt_ad = 0
    cnt_al = 0
    words = []
    #words[] = review_to_wordlist(review)
    words = review_to_wordlist(review)

    #단어 단위로 분해 확인
    pprint(words[:10])

    #전체 단어 수 세기
    cnt_Total.append(len(words))
    
    #각 단어 수 세기
    for word in words:
        tmp = word.split('/')[1]
        if tmp == "Noun": cnt_n += 1
        elif tmp  == "Verb": cnt_v += 1
        elif tmp  == "Adjective": cnt_ad += 1
        elif tmp  == "Alpha": cnt_al += 1
    ratio_Noun.append(cnt_n/len(words))
    ratio_Verb.append(cnt_v/len(words))
    ratio_Adject.append(cnt_ad/len(words))
    ratio_Alpha.append(cnt_al/len(words))
# EXO_words = dict(zip(titles, cnt_Total, ratio_Noun, ratio_Verb, ratio_Adject, ratio_Alpha))

# print(title, "\n", cnt_Total, "\n", ratio_Noun, "\n", ratio_Verb, "\n", ratio_Adject, "\n", ratio_Alpha)
EXO_df_fin = pd.DataFrame({'곡 제목':titles, '총 단어수':cnt_Total, '명사':ratio_Noun, '동사':ratio_Verb, '형용사':ratio_Adject, '영어':ratio_Alpha})
EXO_df_fin.head()
# Out:
# ['제발/Noun',
#  '이제/Noun',
#  '그만/Modifier',
#  '밤/Noun',
#  '이/Josa',
#  '눈/Noun',
#  '을/Josa',
#  '멀다/Adjective',
#  '끄다/Verb',
#  '하니/Noun']
# ['Yo/Alpha',
#  'I/Alpha',
#  'Just/Alpha',
#  'wanna/Alpha',
#  'know/Alpha',
#  'youTime/Alpha',
#  'for/Alpha',
#  'confessionTime/Alpha',
#  'for/Alpha',
#  'confessionPut/Alpha']
# ['첫/Modifier',
#  '눈/Noun',
#  '오다/Verb',
#  '이렇다/Adjective',
#  '오후/Noun',
#  '에/Josa',
#  '너/Noun',
#  '에게/Josa',
#  '전화/Noun',
#  '를/Josa']
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# ['보이지/Noun',
#  '않다/Verb',
#  '널/Noun',
#  '찾다/Verb',
#  '애쓰다/Verb',
#  '들리다/Verb',
#  '않다/Verb',
#  '널/Noun',
#  '들다/Verb',
#  '애쓰다/Verb']
# ['차갑다/Adjective',
#  '서/Modifier',
#  '롤/Noun',
#  '겨눈/Noun',
#  '채날/Noun',
#  '이/Josa',
#  '선/Noun',
#  '듯/Noun',
#  '그/Noun',
#  '목소리/Noun']
# ['설레다/Adjective',
#  '부풀다/Verb',
#  '눈/Noun',
#  '을/Josa',
#  '뜨다/Verb',
#  '아침/Noun',
#  '선물/Noun',
#  '의/Josa',
#  '리본/Noun',
#  '끈/Noun']
# ['I/Alpha',
#  'cant/Alpha',
#  'believe/Alpha',
#  '기다리다/Verb',
#  '이렇다/Adjective',
#  '느끼다/Verb',
#  '듣다/Verb',
#  '싶다/Verb',
#  '그녀/Noun',
#  '는/Josa']
# ['yo/Alpha',
#  'okay/Alpha',
#  '나/Noun',
#  '혹시/Noun',
#  '모르다/Verb',
#  '경고/Noun',
#  '하다/Verb',
#  '지금/Noun',
#  '위험하다/Adjective',
#  '자꾸/Noun']
# ['Oh/Alpha',
#  'Yeah/Alpha',
#  'CmonTake/Alpha',
#  'your/Alpha',
#  'time/Alpha',
#  '왠지/Adverb',
#  '두/Determiner',
#  '근대/Noun',
#  '는/Josa',
#  '밤/Noun']
# ['이/Noun',
#  '거리/Noun',
#  '는/Josa',
#  '완전/Noun',
#  '난리/Noun',
#  '야/Josa',
#  '사람/Noun',
#  '들/Suffix',
#  '사이/Noun',
#  '는/Josa']
# ['조그만/Noun',
#  '날갯짓널/Noun',
#  '향/Noun',
#  '한/Josa',
#  '이끌다/Verb',
#  '림/Noun',
#  '나/Noun',
#  '에게/Josa',
#  '따라오다/Verb',
#  '손짓/Noun']
# ['그렇게/Adverb',
#  '날/Noun',
#  '보고/Noun',
#  '웃다/Verb',
#  'Girl/Alpha',
#  'dont/Alpha',
#  'you/Alpha',
#  'know/Alpha',
#  '아무렇다/Adjective',
#  '않다/Verb']
# ['She/Alpha',
#  'got/Alpha',
#  'me/Alpha',
#  'gone/Alpha',
#  'crazy/Alpha',
#  '왜/Noun',
#  '심장/Noun',
#  '이/Josa',
#  '뛰다/Verb',
#  '넌/Noun']
# ['마음/Noun',
#  '과/Josa',
#  '반대/Noun',
#  '로/Josa',
#  '아프다/Adjective',
#  '말/Noun',
#  '이/Josa',
#  '나오다/Verb',
#  '너/Noun',
#  '를/Josa']
# ['Shimmie/Alpha',
#  'shimmie/Alpha',
#  'Ko/Alpha',
#  'Ko/Alpha',
#  'BopI/Alpha',
#  'think/Alpha',
#  'I/Alpha',
#  'like/Alpha',
#  'it/Alpha',
#  '긴장/Noun']
# ['내/Noun',
#  '낡다/Adjective',
#  '기타/Noun',
#  '를/Josa',
#  '들다/Verb',
#  '하다/Verb',
#  '못/Noun',
#  '한/Josa',
#  '고백/Noun',
#  '을/Josa']
# ['낡다/Adjective',
#  '일기장/Noun',
#  '먼지/Noun',
#  '를/Josa',
#  '털다/Verb',
#  '문득/Noun',
#  '펼치다/Verb',
#  '곳/Noun',
#  '그/Noun',
#  '속/Noun']
# ['어느새다/Adjective',
#  '우리/Noun',
#  '함께/Adverb',
#  '하다/Verb',
#  '다섯/Noun',
#  '번째/Suffix',
#  '크리스마스/Noun',
#  '어느덧다/Adjective',
#  '우리/Noun',
#  '꽤/Noun']
# ['거리/Noun',
#  '에/Josa',
#  '하나/Noun',
#  '둘/Noun',
#  '늘다/Verb',
#  '불빛/Noun',
#  '처럼/Josa',
#  '다가오다/Verb',
#  '하얗다/Adjective',
#  '겨울/Noun']
# ['똑바로/Noun',
#  '보다/Verb',
#  'Whats/Alpha',
#  'the/Alpha',
#  'situation/Alpha',
#  '당황/Noun',
#  '한/Josa',
#  '너/Noun',
#  '의/Josa',
#  '시선/Noun']
# ['머뭇거리다/Verb',
#  '마/Noun',
#  'Move/Alpha',
#  'on/Alpha',
#  '자/Noun',
#  '시간/Noun',
#  '이/Josa',
#  '없다/Adjective',
#  '너/Noun',
#  '의/Josa']
# ['BabyOoh/Alpha',
#  'Yeah/Alpha',
#  'Oh/Alpha',
#  '여기/Noun',
#  '희다/Adjective',
#  '눈/Noun',
#  '위/Noun',
#  '에/Josa',
#  '너/Noun',
#  '의/Josa']
# ['yeah/Alpha',
#  'yeah/Alpha',
#  'yeahyeah/Alpha',
#  'yeah/Alpha',
#  'yeah/Alpha',
#  'yeahOh/Alpha',
#  'yeah/Alpha',
#  'yeahoh/Alpha',
#  'yeah/Alpha',
#  'yeah/Alpha']
# ['천사/Noun',
#  '의/Josa',
#  '얼굴/Noun',
#  '로/Josa',
#  '내게로/Noun',
#  '오다/Verb',
#  '미스터리/Noun',
#  '너/Modifier',
#  '란/Noun',
#  '온기/Noun']
# ['같다/Adjective',
#  '나라/Noun',
#  '에/Josa',
#  '태어나다/Verb',
#  '같다/Adjective',
#  '언어/Noun',
#  '로/Josa',
#  '말/Noun',
#  '을/Josa',
#  '하다/Verb']
# ['Ooh/Alpha',
#  'yeah/Alpha',
#  'yeah/Alpha',
#  '-/Punctuation',
#  'yeah/Alpha',
#  'oh/Alpha',
#  '눈/Noun',
#  '으로/Josa',
#  '널/Noun',
#  '기억/Noun']
# ['더/Noun',
#  '는/Josa',
#  '망설이다/Verb',
#  '마/Noun',
#  '제발/Noun',
#  '내/Noun',
#  '심장/Noun',
#  '을/Josa',
#  '거두다/Verb',
#  '가다/Verb']
# ['악몽/Noun',
#  '을/Josa',
#  '끄다/Verb',
#  '울다/Verb',
#  '그대/Noun',
#  '를/Josa',
#  '안다/Verb',
#  '전/Noun',
#  '에/Josa',
#  '꿈/Noun']
# ['세/Noun',
#  '번/Noun',
#  '까진/Josa',
#  '부딪히다/Verb',
#  '보다/Verb',
#  '여섯/Noun',
#  '번/Noun',
#  '쯤/Suffix',
#  '울/Modifier',
#  '지라/Noun']
# ['Oh/Alpha',
#  '태양/Noun',
#  '이/Josa',
#  '뜨다/Verb',
#  '널/Noun',
#  '찾다/Verb',
#  '지도/Noun',
#  '를/Josa',
#  '들다/Verb',
#  '좌표/Noun']
#                              곡 제목  총 단어수        명사        동사       형용사  \
# 0                       Obsession    411  0.265207  0.201946  0.043796
# 1                      Confession    265  0.173585  0.086792  0.033962
# 2                             첫 눈    314  0.442675  0.203822  0.085987
# 3  12월의 기적 (Miracles in December)    262  0.435115  0.229008  0.064885
# 4                       Love Shot    263  0.243346  0.117871  0.038023
#
#          영어
# 0  0.357664
# 1  0.615094
# 2  0.031847
# 3  0.003817
# 4  0.437262

# %%
# 트와이스 노래별 가사의 단어 종류별 개수 (조사는 무의미하므로 포함 안함)
cnt_Total = []
ratio_Noun = []
ratio_Verb = []
ratio_Adject = []
ratio_Alpha = []
titles = []

#단어를 품사 단위로 (각 가사별로 조사할 예정)
for review, title in zip(TW_final["가사"], TW_final["곡 제목"]):
    titles.append(title)
    cnt_n = 0
    cnt_v = 0
    cnt_ad = 0
    cnt_al = 0
    words = []
    #words[] = review_to_wordlist(review)
    words = review_to_wordlist(review)

    #단어 단위로 분해 확인
    pprint(words[:10])

    #전체 단어 수 세기
    cnt_Total.append(len(words))
    
    #각 단어 수 세기
    for word in words:
        tmp = word.split('/')[1]
        if tmp == "Noun": cnt_n += 1
        elif tmp  == "Verb": cnt_v += 1
        elif tmp  == "Adjective": cnt_ad += 1
        elif tmp  == "Alpha": cnt_al += 1
    ratio_Noun.append(cnt_n/len(words))
    ratio_Verb.append(cnt_v/len(words))
    ratio_Adject.append(cnt_ad/len(words))
    ratio_Alpha.append(cnt_al/len(words))
    
TW_df_fin = pd.DataFrame({'곡 제목':titles, '총 단어수':cnt_Total, '명사':ratio_Noun, '동사':ratio_Verb, '형용사':ratio_Adject, '영어':ratio_Alpha})
TW_df_fin.head()
# Out:
# ['알람/Noun',
#  '이/Josa',
#  '울리다/Verb',
#  'Ring/Alpha',
#  'ring/Alpha',
#  'a/Alpha',
#  'ling/Alpha',
#  '서로/Noun',
#  '의/Josa',
#  '눈길/Noun']
# ['I/Alpha',
#  'know/Alpha',
#  'I/Alpha',
#  'want/Alpha',
#  'it/Alpha',
#  '입/Noun',
#  '에/Josa',
#  '바르다/Verb',
#  '소린/Noun',
#  '이제/Noun']
# ['지금/Noun',
#  '하늘/Noun',
#  '구름/Noun',
#  '색/Noun',
#  '은/Josa',
#  'Tropical/Alpha',
#  'yeah/Alpha',
#  '저/Noun',
#  '태양/Noun',
#  '빨갛다/Adjective']
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# ['그렇다/Adjective',
#  '날/Noun',
#  '이/Josa',
#  '있다/Adjective',
#  '갑자기/Noun',
#  '혼자/Noun',
#  '인/Josa',
#  '것/Noun',
#  '만/Josa',
#  '같다/Adjective']
# ['매년/Noun',
#  '12월/Number',
#  '달력/Noun',
#  '을/Josa',
#  '넘다/Verb',
#  '때/Noun',
#  '마다/Josa',
#  '시작/Noun',
#  '되다/Verb',
#  '그/Noun']
# ['Hey/Alpha',
#  'boyLook/Alpha',
#  'Im/Alpha',
#  'gonna/Alpha',
#  'make/Alpha',
#  'thissimple/Alpha',
#  'for/Alpha',
#  'you/Alpha',
#  'you/Alpha',
#  'got/Alpha']
# ['나나/Noun',
#  '나/Josa',
#  '나나/Noun',
#  '나/Josa',
#  'You/Alpha',
#  'and/Alpha',
#  'me/Alpha',
#  'in/Alpha',
#  'the/Alpha',
#  'moonlight/Alpha']
# ['Yeah/Alpha',
#  'Yeah/Alpha',
#  'Yeah/Alpha',
#  'YeahCome/Alpha',
#  'and/Alpha',
#  'be/Alpha',
#  'my/Alpha',
#  'love/Alpha',
#  'Come/Alpha',
#  'and/Alpha']
# ['매일/Noun',
#  '같이/Josa',
#  '영화/Noun',
#  '속/Noun',
#  '에서나/Josa',
#  '책/Noun',
#  '속/Noun',
#  '에서나/Josa',
#  '드라마/Noun',
#  '속/Noun']
# ['매일/Noun',
#  '울리다/Verb',
#  '벨/Modifier',
#  '벨/Modifier',
#  '벨/Modifier',
#  '이/Modifier',
#  '젠/Noun',
#  '나르다/Verb',
#  '배려/Noun',
#  '해주다/Verb']
# ['열두시/Noun',
#  '가/Josa',
#  '되다/Verb',
#  '닫히다/Verb',
#  '조금/Noun',
#  '만/Josa',
#  '서두르다/Verb',
#  '주다/Verb',
#  'Knock/Alpha',
#  'knock/Alpha']
# ['이르다/Verb',
#  '못/VerbPrefix',
#  '하다/Verb',
#  '저러다/Verb',
#  '못/VerbPrefix',
#  '하다/Verb',
#  '그저/Adverb',
#  '바라보다/Verb',
#  'ba/Alpha',
#  '-/Punctuation']
# ['설레다/Adjective',
#  'Me/Alpha',
#  'Likey/Alpha',
#  'Me/Alpha',
#  'Likey/Alpha',
#  'Likey/Alpha',
#  'Likey/Alpha',
#  'Me/Alpha',
#  'Likey/Alpha',
#  'Likey/Alpha']
# ['모두/Noun',
#  '나르다/Verb',
#  '가지/Noun',
#  '고/Josa',
#  '매일/Noun',
#  '가만/Adverb',
#  '안/Noun',
#  '두다/Verb',
#  '너무/Adverb',
#  '예쁘다/Adjective']
# ['Trying/Alpha',
#  'to/Alpha',
#  'let/Alpha',
#  'you/Alpha',
#  'knowSign/Alpha',
#  '을/Josa',
#  '보내다/Verb',
#  'signal/Alpha',
#  '보내다/Verb',
#  'I/Alpha']
# ['Uh/Alpha',
#  'yeah/Alpha',
#  'yeah/Alpha',
#  '어둠/Noun',
#  '이/Josa',
#  '짙다/Adjective',
#  '깔리다/Verb',
#  '이/Noun',
#  '밤/Noun',
#  '홀로/Noun']
# ['네/Noun',
#  '눈/Noun',
#  '은/Josa',
#  '가시/Noun',
#  '박히다/Verb',
#  'Diamond/Alpha',
#  '같다/Adjective',
#  '애/Noun',
#  '천사/Noun',
#  '와/Josa']
# ['물속/Noun',
#  '에서/Josa',
#  '막히다/Verb',
#  '귀/Noun',
#  '를/Josa',
#  '뚫다/Verb',
#  '울리다/Verb',
#  '날/Noun',
#  '부르다/Verb',
#  '목소리/Noun']
# ['The/Alpha',
#  'best/Alpha',
#  'thing/Alpha',
#  'I/Alpha',
#  'ever/Alpha',
#  'didDecember/Alpha',
#  '1년/Number',
#  '의/Foreign',
#  '끝/Noun',
#  '을/Josa']
# ['Its/Alpha',
#  'a/Alpha',
#  'showBut/Alpha',
#  'you/Alpha',
#  'shouldnt/Alpha',
#  'forgetI/Alpha',
#  'know/Alpha',
#  'what/Alpha',
#  'you/Alpha',
#  'areUh/Alpha']
# ['I/Alpha',
#  'believeIm/Alpha',
#  'a/Alpha',
#  'believer/Alpha',
#  'oh/Alpha',
#  'yeahBelieverYoure/Alpha',
#  'on/Alpha',
#  'my/Alpha',
#  'mind/Alpha',
#  '네/Noun']
# ['Woah/Alpha',
#  '-/Punctuation',
#  'uh/Alpha',
#  '-/Punctuation',
#  'uh/Alpha',
#  'We/Alpha',
#  'just/Alpha',
#  'go/Alpha',
#  'hardWe/Alpha',
#  'just/Alpha']
# ['매일/Noun',
#  '이/Josa',
#  '별다르다/Adjective',
#  '것/Noun',
#  '없다/Adjective',
#  '기억/Noun',
#  '들/Suffix',
#  '이/Josa',
#  '변하다/Adjective',
#  '것/Noun']
# ['작다/Adjective',
#  '소리/Noun',
#  '들/Suffix',
#  '의/Josa',
#  '기적/Noun',
#  '꿈속/Noun',
#  '의/Josa',
#  '믿음/Noun',
#  '을/Josa',
#  '기억/Noun']
# ['Ooh/Alpha',
#  'no/Alpha',
#  'Im/Alpha',
#  'gonna/Alpha',
#  'bring/Alpha',
#  'it/Alpha',
#  'back/Alpha',
#  'hmmBring/Alpha',
#  'it/Alpha',
#  'back/Alpha']
# ['뱉다/Verb',
#  '숨/Noun',
#  '을/Josa',
#  '말다/Verb',
#  '뒤/Noun',
#  '한숨/Noun',
#  '만/Josa',
#  '남기다/Verb',
#  '두다/Verb',
#  '지네/Noun']
# ['말르다/Adjective',
#  '버리다/Verb',
#  '내/Noun',
#  '두/Noun',
#  '눈/Noun',
#  '에/Josa',
#  '바람/Noun',
#  '이/Josa',
#  '불어/Noun',
#  '시리다/Adjective']
# ['Pull/Alpha',
#  'the/Alpha',
#  'trigger/Alpha',
#  '하다/Verb',
#  '방/Noun',
#  '에/Josa',
#  'Shot/Alpha',
#  '기회/Noun',
#  '는/Josa',
#  '딱/Adverb']
# ['Like/Alpha',
#  'a/Alpha',
#  'bulldozer/Alpha',
#  'Like/Alpha',
#  'a/Alpha',
#  'tankLike/Alpha',
#  'a/Alpha',
#  'soldier/Alpha',
#  '무너/Noun',
#  '뜨다/Verb']
# ['Im/Alpha',
#  'hearing/Alpha',
#  'all/Alpha',
#  'the/Alpha',
#  'alarms/Alpha',
#  'ring/Alpha',
#  '-/Punctuation',
#  'a/Alpha',
#  '-/Punctuation',
#  'lingThey/Alpha']
#               곡 제목  총 단어수        명사        동사       형용사        영어
# 0  I CAN'T STOP ME    350  0.231429  0.151429  0.051429  0.420000
# 1      MORE & MORE    324  0.250000  0.169753  0.055556  0.435185
# 2            FANCY    311  0.363344  0.109325  0.096463  0.311897
# 3     Feel Special    285  0.308772  0.105263  0.122807  0.284211
# 4    Merry & Happy    232  0.340517  0.189655  0.129310  0.081897

# %%
# 구분 추가 (엑소인지 트와이스인지 구별)
for i in range(len(EXO_df_fin)):
    EXO_df_fin['구분'] = 0
for i in range(len(TW_df_fin)):
    TW_df_fin['구분'] = 1
EXO_df_fin.head()
# Out:
#                              곡 제목  총 단어수        명사        동사       형용사  \
# 0                       Obsession    411  0.265207  0.201946  0.043796
# 1                      Confession    265  0.173585  0.086792  0.033962
# 2                             첫 눈    314  0.442675  0.203822  0.085987
# 3  12월의 기적 (Miracles in December)    262  0.435115  0.229008  0.064885
# 4                       Love Shot    263  0.243346  0.117871  0.038023
#
#          영어  구분
# 0  0.357664   0
# 1  0.615094   0
# 2  0.031847   0
# 3  0.003817   0
# 4  0.437262   0

# %%
# 엑소, 트와이스 데이터 합치기
All_df = pd.concat([EXO_df_fin, TW_df_fin])

# %%
# 문자열, 무의미한 데이터 총 단어수 삭제
All_df.drop('곡 제목', axis = 1, inplace = True) # 문자열이라 삭제
All_df.drop('총 단어수', axis = 1, inplace = True) # 무의미한 데이터라 삭제

# %%
# 데이터들 순서 무작위로 섞어주기
import sklearn
All_df_shuffled = sklearn.utils.shuffle(All_df)
# Train - Test 데이터 나누기 (7:3 비율로)

data_cnt = len(All_df_shuffled)

train_cnt = int(data_cnt*0.7) + 1

Train_df_set = All_df_shuffled[:train_cnt]
Test_df_set = All_df_shuffled[train_cnt:]
print("Train data count : ", len(Train_df_set)) # 42
print("Test data count : ", len(Test_df_set))   # 18
# Out:
# Train data count :  43
# Test data count :  17

# %%
# 데이터 셋 준비
X_Train = Train_df_set.drop("구분", axis=1) # 구분 열 버리고 저장
Y_Train = Train_df_set["구분"] # 구분 열 정보만 저장
X_Test = Test_df_set.drop("구분", axis=1).copy() # 구분 열 버리고 저장

# %%
# 기계 학습용 패키지 선언
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron

#from sklearn.neural_network import MLPClassifier
#from sklearn.feature_extraction.text import CountVectorizer

# %%
# 1 - Logistic Regression
log_reg = LogisticRegression(solver = 'lbfgs')
log_reg.fit(X_Train, Y_Train)

Y_Pred = log_reg.predict(X_Test)
score_log_reg = round(log_reg.score(X_Train, Y_Train) * 100, 2)
print("Logistic Regression Score : ",score_log_reg)
# Out:
# Logistic Regression Score :  58.14

# %%
# 2 - Linear SVC
lin_svc = LinearSVC()
lin_svc.fit(X_Train, Y_Train)

Y_Pred = lin_svc.predict(X_Test)
score_lin_svc = round(lin_svc.score(X_Train, Y_Train) * 100, 2)
print("Linear SVC Score : ",score_lin_svc)
# Out:
# Linear SVC Score :  67.44

# %%
# 3 - Decision Tree
dec_tree = DecisionTreeClassifier()
dec_tree.fit(X_Train, Y_Train)

Y_Pred = dec_tree.predict(X_Test)
score_dec_tree = round(dec_tree.score(X_Train, Y_Train) * 100, 2)
print("Decision Tree Score : ",score_dec_tree)
# Out:
# Decision Tree Score :  100.0

# %%
# 4 - Gaussian Naive Bayes
gaus = GaussianNB()
gaus.fit(X_Train, Y_Train)

Y_Pred = gaus.predict(X_Test)
score_gaus = round(gaus.score(X_Train, Y_Train) * 100, 2)
print("Gaussian Naive Bayes Score : ",score_gaus)
# Out:
# Gaussian Naive Bayes Score :  67.44

# %%
# 5 - Stochastic Gradient Descent
sgd = SGDClassifier()
sgd.fit(X_Train, Y_Train)

Y_Pred = sgd.predict(X_Test)
score_sgd = round(sgd.score(X_Train, Y_Train) * 100, 2)
print("Stochastic Gradient Descent Score : ",score_sgd)
# Out:
# Stochastic Gradient Descent Score :  65.12

# %%
# 6 - Support Vector Machines
svc = SVC()
solver = 'liblinear'
svc.fit(X_Train, Y_Train)

Y_Pred = svc.predict(X_Test)
score_svc = round(svc.score(X_Train, Y_Train) * 100, 2)
print("Support Vector Machines Score : ",score_svc)
# Out:
# Support Vector Machines Score :  67.44

# %%
# 7 - KNN
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_Train, Y_Train)

Y_Pred = knn.predict(X_Test)
score_knn = round(knn.score(X_Train, Y_Train) * 100, 2)
print("KNN Score : ",score_knn)
# Out:
# KNN Score :  83.72

# %%
# 8 - Random Forest
ran_fore = RandomForestClassifier(n_estimators = 100)
ran_fore.fit(X_Train, Y_Train)

Y_Pred = ran_fore.predict(X_Test)
score_ran_fore = round(ran_fore.score(X_Train, Y_Train) * 100, 2)
print("Random Forest Score : ",score_ran_fore)
# Out:
# Random Forest Score :  100.0

# %%
# 9 - Perceptron
perc = Perceptron()
perc.fit(X_Train, Y_Train)

Y_Pred = perc.predict(X_Test)
score_perc = round(perc.score(X_Train, Y_Train) * 100, 2)
print("Perceptron Score : ",score_perc)
# Out:
# Perceptron Score :  60.47

# %%
# 최종 결과 스코어 확인
model_res = pd.DataFrame({
    'Model name': ['Logistic Regression', 'Linear SVC', 'Decision Tree', 
                   'Gaussian Naive Bayes', 'Stochastic Gradient Descent', 
                   'Support Vector Machines', 'KNN', 'Random Forest', 
                   'Perceptron'],
    'Score': [score_log_reg, score_lin_svc, score_dec_tree, score_gaus, 
             score_sgd, score_svc, score_knn, score_ran_fore, score_perc]})
model_res.sort_values(by = 'Score', ascending = False)
# Out:
#                     Model name   Score
# 2                Decision Tree  100.00
# 7                Random Forest  100.00
# 6                          KNN   83.72
# 1                   Linear SVC   67.44
# 3         Gaussian Naive Bayes   67.44
# 5      Support Vector Machines   67.44
# 4  Stochastic Gradient Descent   65.12
# 8                   Perceptron   60.47
# 0          Logistic Regression   58.14

# %%
# csv 파일 생성
final_res = pd.DataFrame({
    '명사' : Test_df_set['명사'],
    '동사' : Test_df_set['동사'],
    '형용사' : Test_df_set['형용사'],
    '영어' : Test_df_set['영어'],
    '구분(엑소:0 / 트와이스:1)' : Y_Pred})
final_res.to_csv('Final_Results_TextMining_Assignment.csv', mode = 'w', encoding = 'utf-8-sig', index = False)

# %%
final_check = pd.read_csv('Final_Results_TextMining_Assignment.csv')
final_check.describe()
# Out:
#               명사         동사        형용사         영어  구분(엑소:0 / 트와이스:1)
# count  17.000000  17.000000  17.000000  17.000000          17.000000
# mean    0.341944   0.167188   0.055083   0.255503           0.235294
# std     0.102762   0.051311   0.031696   0.197370           0.437237
# min     0.176923   0.092308   0.011538   0.018587           0.000000
# 25%     0.244068   0.131206   0.038023   0.061404           0.000000
# 50%     0.353846   0.168182   0.042705   0.245536           0.000000
# 75%     0.442675   0.203822   0.083333   0.383051           0.000000
# max     0.472119   0.269461   0.122807   0.607692           1.000000
